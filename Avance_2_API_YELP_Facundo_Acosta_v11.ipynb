# %%
# ============================================
# AVANCE #2 - CONEXIÓN A API YELP
# InsightReach - Facundo Acosta - Científico de Datos Junior
# ============================================

# %% [markdown]
# # Avance #2 - Conexión a API Yelp
# ## Integración de Datos Externos para Análisis de Mercado
#
# ### Objetivo
# Conectar con la API de Yelp para obtener datos de negocios locales en Miami y enriquecer el análisis de clientes con información contextual del mercado.

# %%
# =============================================================================
# CONFIGURACIÓN INICIAL Y LIBRERÍAS
# =============================================================================
import requests
import pandas as pd
import os
import load_dotenv
import time  
import json  

print("📦 Librerías importadas correctamente")
# Out:
# 📦 Librerías importadas correctamente

# %% [markdown]
# ## 1. Configuración y Autenticación con API Yelp

# %%
# =============================================================================
# 1.1 CONFIGURACIÓN INICIAL Y VARIABLES DE ENTORNO
# =============================================================================
print("=" * 70)
print("1. CONFIGURACIÓN Y AUTENTICACIÓN CON API YELP")
print("=" * 70)

print("\n1.1 CONFIGURACIÓN INICIAL")
print("-" * 50)

try:
    # Cargar variables de entorno
    load_dotenv.load_dotenv()
    print("✅ Variables de entorno cargadas correctamente")
    
    # Configurar credenciales de la API
    cliente_id = os.getenv("CLIENTE_ID")
    api_key = os.getenv("API_KEY")
    
    if not api_key:
        raise ValueError("API_KEY no encontrada en variables de entorno")
    
    print("✅ Credenciales de API obtenidas correctamente")
    print(f"🔑 Cliente ID: {cliente_id[:10]}...") if cliente_id else print("⚠️ Cliente ID no encontrado")
    print(f"🔑 API Key: {api_key[:10]}...") if api_key else print("❌ API Key no encontrada")
    
except Exception as e:
    print(f"❌ Error en la configuración: {e}")
    print("⚠️ Verificar que el archivo .env exista y contenga:")
    print("   - CLIENTE_ID=tu_cliente_id")
    print("   - API_KEY=tu_api_key")
    exit()
# Out:
# ======================================================================
# 1. CONFIGURACIÓN Y AUTENTICACIÓN CON API YELP
# ======================================================================
#
# 1.1 CONFIGURACIÓN INICIAL
# --------------------------------------------------
# ✅ Variables de entorno cargadas correctamente
# ✅ Credenciales de API obtenidas correctamente
# 🔑 Cliente ID: GWOCZh9-Bm...
# 🔑 API Key: FHVvXoNmTX...

# %% [markdown]
# ## 2. Configuración de la Solicitud a la API

# %%
# =============================================================================
# 1.2 CONFIGURACIÓN DE LA SOLICITUD API
# =============================================================================
print("\n1.2 CONFIGURACIÓN DE LA SOLICITUD API")
print("-" * 50)

# Parámetros de la búsqueda - Enfocado en bares de Miami
url = "https://api.yelp.com/v3/businesses/search"
ciudad = 'Miami'  # Ciudad filtrada del avance anterior
params = {
    'term': 'bar',          # Tipo de negocio a buscar (bares)
    'location': ciudad,     # Ciudad objetivo
    'limit': 50,            # Número máximo de resultados
    'sort_by': 'rating',    # Ordenar por calificación
    'radius': 10000         # Radio de búsqueda en metros (10km)
}

headers = {
    'Authorization': f'Bearer {api_key}',
    'Accept': 'application/json'
}

print(f"🔍 Búsqueda configurada para: {ciudad}")
print(f"📋 Tipo de negocio: {params['term']}")
print(f"📊 Límite de resultados: {params['limit']}")
print(f"⭐ Ordenamiento: {params['sort_by']}")
print(f"🗺️  Radio de búsqueda: {params['radius']} metros")

# Mostrar URL de la solicitud (sin API key por seguridad)
url_segura = f"{url}?term={params['term']}&location={params['location']}&limit={params['limit']}"
print(f"🌐 URL de solicitud: {url_segura}")
# Out:
# 1.2 CONFIGURACIÓN DE LA SOLICITUD API
# --------------------------------------------------
# 🔍 Búsqueda configurada para: Miami
# 📋 Tipo de negocio: bar
# 📊 Límite de resultados: 50
# ⭐ Ordenamiento: rating
# 🗺️  Radio de búsqueda: 10000 metros
# 🌐 URL de solicitud: https://api.yelp.com/v3/businesses/search?term=bar&location=Miami&limit=50

# %% [markdown]
# ## 3. Conexión y Solicitud a la API

# %%
# =============================================================================
# 1.3 REALIZAR LA SOLICITUD A LA API
# =============================================================================
print("\n1.3 SOLICITUD A LA API DE YELP")
print("-" * 50)

try:
    print("⏳ Realizando solicitud a la API...")
    start_time = time.time()
    response = requests.get(url=url, params=params, headers=headers)
    end_time = time.time()
    
    print(f"⏱️  Tiempo de respuesta: {end_time - start_time:.2f} segundos")
    print(f"📡 Código de estado HTTP: {response.status_code}")
    
    # Manejo de diferentes códigos de estado
    if response.status_code == 200:
        print("✅ Conexión exitosa con la API de Yelp")
        data = response.json()
        total_negocios = len(data.get('businesses', []))
        print(f"📊 Número de negocios obtenidos: {total_negocios}")
        
    elif response.status_code == 401:
        print("❌ Error de autenticación: API key inválida o no autorizada")
        print("⚠️ Verificar que la API key sea correcta y esté activa")
        print("🔗 Documentación: https://www.yelp.com/developers/documentation/v3/authentication")
        exit()
        
    elif response.status_code == 429:
        print("❌ Límite de tasa excedido: Demasiadas solicitudes")
        print("⚠️ Esperar antes de realizar más solicitudes")
        print("💡 Yelp limita a 5000 solicitudes por día")
        exit()
        
    elif response.status_code == 400:
        print("❌ Solicitud incorrecta: Parámetros inválidos")
        print(f"📋 Mensaje: {response.text[:200]}...")
        exit()
        
    else:
        print(f"❌ Error en la solicitud: Código {response.status_code}")
        print(f"📋 Mensaje: {response.text[:200]}...")
        exit()
        
except requests.exceptions.ConnectionError:
    print("❌ Error de conexión: No se pudo conectar a la API de Yelp")
    print("⚠️ Verificar conexión a internet")
    exit()
    
except requests.exceptions.Timeout:
    print("❌ Timeout: La solicitud tardó demasiado tiempo")
    print("⚠️ Intentar nuevamente o verificar la conexión")
    exit()
    
except requests.exceptions.RequestException as e:
    print(f"❌ Error en la solicitud: {e}")
    exit()
    
except Exception as e:
    print(f"❌ Error inesperado: {e}")
    exit()
# Out:
# 1.3 SOLICITUD A LA API DE YELP
# --------------------------------------------------
# ⏳ Realizando solicitud a la API...
# ⏱️  Tiempo de respuesta: 1.82 segundos
# 📡 Código de estado HTTP: 200
# ✅ Conexión exitosa con la API de Yelp
# 📊 Número de negocios obtenidos: 50

# %% [markdown]
# ## 4. Validación de Datos Recibidos

# %%
# =============================================================================
# 1.4 VALIDACIÓN DE DATOS RECIBIDOS
# =============================================================================
print("\n1.4 VALIDACIÓN DE DATOS RECIBIDOS")
print("-" * 50)

if 'businesses' in data and data['businesses']:
    primer_negocio = data['businesses'][0]
    print("✅ Datos recibidos correctamente")
    print(f"📝 Primer negocio: {primer_negocio.get('name', 'N/A')}")
    print(f"⭐ Calificación: {primer_negocio.get('rating', 'N/A')}/5")
    print(f"💬 Reseñas: {primer_negocio.get('review_count', 'N/A')}")
    print(f"🏷️  Categorías: {', '.join([cat['title'] for cat in primer_negocio.get('categories', [])])}")
    print(f"📍 Ubicación: {primer_negocio.get('location', {}).get('address1', 'N/A')}")
    
    # Información adicional del primer negocio
    if 'price' in primer_negocio:
        print(f"💰 Nivel de precio: {primer_negocio['price']}")
    if 'phone' in primer_negocio:
        print(f"📞 Teléfono: {primer_negocio['phone']}")
        
else:
    print("❌ No se recibieron datos de negocios")
    print("⚠️ Posibles causas:")
    print("   - No hay negocios que coincidan con la búsqueda")
    print("   - Error en los parámetros de búsqueda")
    print("   - Problemas con la API")
    print("💡 Sugerencia: Intentar con términos de búsqueda más amplios")
    exit()

# Estadísticas generales de los datos
if data['businesses']:
    ratings = [biz.get('rating', 0) for biz in data['businesses']]
    reviews = [biz.get('review_count', 0) for biz in data['businesses']]
    
    print(f"\n📊 Estadísticas generales:")
    print(f"⭐ Calificación promedio: {sum(ratings)/len(ratings):.2f}/5")
    print(f"📈 Calificación máxima: {max(ratings)}/5")
    print(f"📉 Calificación mínima: {min(ratings)}/5")
    print(f"💬 Total de reseñas: {sum(reviews)}")
    print(f"📝 Reseñas promedio por negocio: {sum(reviews)/len(reviews):.1f}")
# Out:
# 1.4 VALIDACIÓN DE DATOS RECIBIDOS
# --------------------------------------------------
# ✅ Datos recibidos correctamente
# 📝 Primer negocio: 9 Feet Under
# ⭐ Calificación: 5.0/5
# 💬 Reseñas: 21
# 🏷️  Categorías: Lounges, Speakeasies, Cocktail Bars
# 📍 Ubicación: 885 SE 14th St
# 📞 Teléfono: +13054146950
#
# 📊 Estadísticas generales:
# ⭐ Calificación promedio: 4.36/5
# 📈 Calificación máxima: 5.0/5
# 📉 Calificación mínima: 3.9/5
# 💬 Total de reseñas: 19912
# 📝 Reseñas promedio por negocio: 398.2

# %% [markdown]
# ## 5. Resumen de la Conexión Exitosa

# %%
# =============================================================================
# 1.5 RESUMEN DE CONEXIÓN EXITOSA
# =============================================================================
print("\n1.5 RESUMEN DE CONEXIÓN")
print("-" * 50)

print("🎯 Conexión a API Yelp completada exitosamente")
print(f"🏙️  Ciudad objetivo: {ciudad}")
print(f"🏢 Tipo de negocio: {params['term']}")
print(f"📊 Negocios obtenidos: {len(data['businesses'])}")
print(f"⭐ Rango de calificaciones: {min(ratings)} - {max(ratings)}/5")
print(f"🔑 Autenticación: Exitosa")
print(f"⏱️  Tiempo de respuesta: {end_time - start_time:.2f} segundos")

# Guardar datos crudos para backup
try:
    with open('yelp_data_raw.json', 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
    print("💾 Datos crudos guardados en 'yelp_data_raw.json'")
except Exception as e:
    print(f"⚠️ Error al guardar datos crudos: {e}")

print("\n" + "=" * 70)
print("PRÓXIMO PASO: Extracción y transformación de datos de negocios")
print("=" * 70)
# Out:
# 1.5 RESUMEN DE CONEXIÓN
# --------------------------------------------------
# 🎯 Conexión a API Yelp completada exitosamente
# 🏙️  Ciudad objetivo: Miami
# 🏢 Tipo de negocio: bar
# 📊 Negocios obtenidos: 50
# ⭐ Rango de calificaciones: 3.9 - 5.0/5
# 🔑 Autenticación: Exitosa
# ⏱️  Tiempo de respuesta: 1.82 segundos
# 💾 Datos crudos guardados en 'yelp_data_raw.json'
#
# ======================================================================
# PRÓXIMO PASO: Extracción y transformación de datos de negocios
# ======================================================================

# %% [markdown]
# ### Checklist de Conexión Exitosa
#
# - [x] ✅ Variables de entorno cargadas correctamente
# - [x] ✅ Credenciales de API validadas
# - [x] ✅ Parámetros de búsqueda configurados
# - [x] ✅ Conexión HTTP exitosa (200)
# - [x] ✅ Datos recibidos y validados
# - [x] ✅ Estadísticas calculadas
# - [x] ✅ Backup de datos crudos creado
#
# ### Consideraciones de Seguridad
#
# - Las credenciales de API se manejan mediante variables de entorno
# - No se exponen keys sensibles en el código
# - Se utiliza archivo .env para configuración segura
# - Los datos se validan antes de procesar

# %%
# Variable para uso en siguientes celdas
response_data = data
print("📋 Datos preparados para el próximo bloque de transformación")
# Out:
# 📋 Datos preparados para el próximo bloque de transformación

# %%
# =============================================================================
# BLOQUE 2: PAGINACIÓN Y RECOLECCIÓN MASIVA DE DATOS
# =============================================================================
print("=" * 70)
print("BLOQUE 2: PAGINACIÓN Y RECOLECCIÓN MASIVA DE DATOS")
print("=" * 70)
# Out:
# ======================================================================
# BLOQUE 2: PAGINACIÓN Y RECOLECCIÓN MASIVA DE DATOS
# ======================================================================

# %% [markdown]
# ## 6. Implementación de Paginación para Múltiples Resultados
#
# ### 🎯 Objetivo:
# Recuperar el máximo número posible de resultados de la API Yelp utilizando paginación, ya que la API limita a 50 resultados por solicitud.

# %%
# =============================================================================
# 6.1 CONFIGURACIÓN DE PAGINACIÓN
# =============================================================================
print("\n6.1 CONFIGURACIÓN DE PAGINACIÓN")
print("-" * 50)

# Parámetros de la búsqueda con enfoque en restaurantes (más resultados)
url = "https://api.yelp.com/v3/businesses/search"
ciudad = 'Miami'

# Configuración optimizada para paginación
params = {
    'term': 'restaurant',    # Cambiado de 'bar' a 'restaurant' para más resultados
    'location': ciudad,      # Ciudad objetivo
    'limit': 50,             # Máximo permitido por la API por página
    'offset': 0,             # Iniciar desde el primer resultado
    'sort_by': 'best_match', # Ordenamiento por mejor coincidencia
    'radius': 15000          # Radio ampliado a 15km
}

headers = {
    'Authorization': f'Bearer {api_key}',
    'Accept': 'application/json'
}

print(f"🔍 Búsqueda configurada para: {ciudad}")
print(f"📋 Tipo de negocio: {params['term']}")
print(f"📊 Límite por página: {params['limit']}")
print(f"🗺️  Radio de búsqueda: {params['radius']} metros")
print("🔄 Configurado para paginación (múltiples solicitudes)")
# Out:
# 6.1 CONFIGURACIÓN DE PAGINACIÓN
# --------------------------------------------------
# 🔍 Búsqueda configurada para: Miami
# 📋 Tipo de negocio: restaurant
# 📊 Límite por página: 50
# 🗺️  Radio de búsqueda: 15000 metros
# 🔄 Configurado para paginación (múltiples solicitudes)

# %%
# =============================================================================
# 6.2 ESTRATEGIA DE PAGINACIÓN
# =============================================================================
print("\n6.2 ESTRATEGIA DE PAGINACIÓN")
print("-" * 50)

all_businesses = []  # Lista para almacenar todos los negocios
max_results = 200    # Número máximo de resultados deseado
current_offset = 0   # Offset inicial
page_number = 1      # Contador de páginas
total_estimated = 0  # Total estimado de resultados

print(f"🎯 Objetivo: Obtener hasta {max_results} negocios")
print("📋 Estrategia:")
print("   - Solicitudes secuenciales con incremento de offset")
print("   - Límite de 50 resultados por página (máximo de Yelp)")
print("   - Pausas entre solicitudes para evitar rate limiting")
print("   - Validación de códigos de estado HTTP")
print("   - Manejo robusto de errores y timeouts")
# Out:
# 6.2 ESTRATEGIA DE PAGINACIÓN
# --------------------------------------------------
# 🎯 Objetivo: Obtener hasta 200 negocios
# 📋 Estrategia:
#    - Solicitudes secuenciales con incremento de offset
#    - Límite de 50 resultados por página (máximo de Yelp)
#    - Pausas entre solicitudes para evitar rate limiting
#    - Validación de códigos de estado HTTP
#    - Manejo robusto de errores y timeouts

# %% [markdown]
# ## 7. Ejecución de Solicitudes Paginadas

# %%
# =============================================================================
# 7.1 SOLICITUDES PAGINADAS A LA API
# =============================================================================
print("\n7.1 SOLICITUDES PAGINADAS A LA API")
print("-" * 50)

try:
    print("⏳ Iniciando proceso de paginación...")
    start_time = time.time()
    
    while len(all_businesses) < max_results:
        # Actualizar el offset para la solicitud actual
        params['offset'] = current_offset
        
        print(f"\n📡 Solicitando página {page_number}: offset {current_offset}")
        
        # Realizar la solicitud con manejo de timeout
        response = requests.get(url=url, params=params, headers=headers, timeout=30)
        
        if response.status_code == 200:
            data = response.json()
            businesses = data.get('businesses', [])
            total_estimated = data.get('total', 0)
            
            if not businesses:
                print("ℹ️ No hay más resultados disponibles")
                break
            
            # Agregar negocios a la lista total
            all_businesses.extend(businesses)
            print(f"✅ Obtenidos {len(businesses)} negocios")
            print(f"📊 Total acumulado: {len(all_businesses)}/{max_results}")
            
            # Mostrar progreso
            if total_estimated > 0:
                progress = (len(all_businesses) / min(total_estimated, max_results)) * 100
                print(f"📈 Progreso: {progress:.1f}%")
            
            # Preparar para la siguiente página
            current_offset += len(businesses)
            page_number += 1
            
            # Verificar condiciones de terminación
            if len(all_businesses) >= max_results:
                print(f"🎯 Máximo de {max_results} resultados alcanzado")
                break
                
            if len(businesses) < params['limit']:
                print("ℹ️ Última página alcanzada")
                break
                
        elif response.status_code == 400:
            print("❌ Error 400: Parámetros inválidos")
            print("💡 Verificar parámetros de búsqueda")
            break
            
        elif response.status_code == 429:
            print("⏰ Límite de tasa excedido. Esperando 2 segundos...")
            time.sleep(2)  # Esperar antes de reintentar
            continue
            
        elif response.status_code == 404:
            print("❌ Error 404: Recurso no encontrado")
            break
            
        else:
            print(f"❌ Error HTTP {response.status_code}")
            print(f"📋 Mensaje: {response.text[:100]}...")
            break
            
        # Pausa estratégica para ser amable con la API
        time.sleep(0.3)
        
    end_time = time.time()
    print(f"\n⏱️  Tiempo total del proceso: {end_time - start_time:.2f} segundos")
    
except requests.exceptions.ConnectionError:
    print("❌ Error de conexión: No se pudo conectar a la API")
    exit()
    
except requests.exceptions.Timeout:
    print("❌ Timeout: La solicitud tardó demasiado tiempo")
    exit()
    
except requests.exceptions.RequestException as e:
    print(f"❌ Error en la solicitud: {e}")
    exit()
    
except Exception as e:
    print(f"❌ Error inesperado: {e}")
    exit()
# Out:
# 7.1 SOLICITUDES PAGINADAS A LA API
# --------------------------------------------------
# ⏳ Iniciando proceso de paginación...
#
# 📡 Solicitando página 1: offset 0
# ✅ Obtenidos 50 negocios
# 📊 Total acumulado: 50/200
# 📈 Progreso: 25.0%
#
# 📡 Solicitando página 2: offset 50
# ✅ Obtenidos 50 negocios
# 📊 Total acumulado: 100/200
# 📈 Progreso: 50.0%
#
# 📡 Solicitando página 3: offset 100
# ✅ Obtenidos 50 negocios
# 📊 Total acumulado: 150/200
# 📈 Progreso: 75.0%
#
# 📡 Solicitando página 4: offset 150
# ✅ Obtenidos 50 negocios
# 📊 Total acumulado: 200/200
# 📈 Progreso: 100.0%
# 🎯 Máximo de 200 resultados alcanzado
#
# ⏱️  Tiempo total del proceso: 8.71 segundos

# %% [markdown]
# ## 8. Validación y Análisis de Datos Obtenidos

# %%
# =============================================================================
# 8.1 VALIDACIÓN DE DATOS OBTENIDOS
# =============================================================================
print("\n8.1 VALIDACIÓN DE DATOS OBTENIDOS")
print("-" * 50)

if all_businesses:
    print(f"✅ Total de negocios obtenidos: {len(all_businesses)}")
    print(f"📊 Número de páginas solicitadas: {page_number - 1}")
    print(f"🔍 Total estimado disponible: {total_estimated} negocios")
    
    # Estadísticas de los primeros y últimos negocios
    primer_negocio = all_businesses[0]
    ultimo_negocio = all_businesses[-1]
    
    print(f"\n📝 Primer negocio: {primer_negocio.get('name', 'N/A')}")
    print(f"   ⭐ Calificación: {primer_negocio.get('rating', 'N/A')}/5")
    print(f"   💬 Reseñas: {primer_negocio.get('review_count', 'N/A')}")
    
    print(f"\n📝 Último negocio: {ultimo_negocio.get('name', 'N/A')}")
    print(f"   ⭐ Calificación: {ultimo_negocio.get('rating', 'N/A')}/5")
    print(f"   💬 Reseñas: {ultimo_negocio.get('review_count', 'N/A')}")
    
    # Calcular estadísticas completas
    ratings = [b.get('rating', 0) for b in all_businesses if b.get('rating') is not None]
    review_counts = [b.get('review_count', 0) for b in all_businesses if b.get('review_count') is not None]
    prices = [b.get('price', 'N/A') for b in all_businesses if b.get('price')]
    
    if ratings:
        print(f"\n📈 Estadísticas de calificaciones:")
        print(f"   ⭐ Promedio: {sum(ratings) / len(ratings):.2f}/5")
        print(f"   📊 Máxima: {max(ratings)}/5")
        print(f"   📉 Mínima: {min(ratings)}/5")
        print(f"   🔢 Count: {len(ratings)} negocios con calificación")
    
    if review_counts:
        print(f"\n💬 Estadísticas de reseñas:")
        print(f"   📝 Total reseñas: {sum(review_counts)}")
        print(f"   📊 Promedio: {sum(review_counts) / len(review_counts):.1f} por negocio")
        print(f"   🏆 Máximo: {max(review_counts)} reseñas")
        print(f"   🔢 Negocios con reseñas: {len(review_counts)}")
    
    if prices:
        price_counts = pd.Series(prices).value_counts()
        print(f"\n💰 Distribución de precios:")
        for price, count in price_counts.items():
            print(f"   {price}: {count} negocios")
    
else:
    print("❌ No se obtuvieron resultados")
    print("💡 Posibles soluciones:")
    print("   - Verificar términos de búsqueda")
    print("   - Probar con una ciudad diferente")
    print("   - Verificar conectividad a internet")
    exit()
# Out:
# 8.1 VALIDACIÓN DE DATOS OBTENIDOS
# --------------------------------------------------
# ✅ Total de negocios obtenidos: 200
# 📊 Número de páginas solicitadas: 4
# 🔍 Total estimado disponible: 5700 negocios
#
# 📝 Primer negocio: Salty Flame
#    ⭐ Calificación: 4.4/5
#    💬 Reseñas: 194
#
# 📝 Último negocio: CRAFT Coral Gables
#    ⭐ Calificación: 4.4/5
#    💬 Reseñas: 286
#
# 📈 Estadísticas de calificaciones:
#    ⭐ Promedio: 4.34/5
#    📊 Máxima: 5.0/5
#    📉 Mínima: 2.7/5
#    🔢 Count: 200 negocios con calificación
#
# 💬 Estadísticas de reseñas:
#    📝 Total reseñas: 107026
#    📊 Promedio: 535.1 por negocio
#    🏆 Máximo: 6887 reseñas
#    🔢 Negocios con reseñas: 200
#
# 💰 Distribución de precios:
#    $$: 99 negocios
#    $$$: 21 negocios
#    $: 13 negocios
#    $$$$: 7 negocios

# %%
# =============================================================================
# 8.2 ANÁLISIS DE CALIDAD DE DATOS
# =============================================================================
print("\n8.2 ANÁLISIS DE CALIDAD DE DATOS")
print("-" * 50)

# Verificar integridad de los datos
print("🔍 Análisis de integridad de datos:")
print(f"   📊 Total de negocios: {len(all_businesses)}")
print(f"   ✅ Negocios con nombre: {sum(1 for b in all_businesses if b.get('name'))}")
print(f"   ⭐ Negocios con calificación: {sum(1 for b in all_businesses if b.get('rating'))}")
print(f"   💬 Negocios con reseñas: {sum(1 for b in all_businesses if b.get('review_count'))}")
print(f"   📍 Negocios con ubicación: {sum(1 for b in all_businesses if b.get('location'))}")
print(f"   📞 Negocios con teléfono: {sum(1 for b in all_businesses if b.get('phone'))}")

# Porcentaje de completitud
completeness = {
    'name': sum(1 for b in all_businesses if b.get('name')) / len(all_businesses) * 100,
    'rating': sum(1 for b in all_businesses if b.get('rating')) / len(all_businesses) * 100,
    'review_count': sum(1 for b in all_businesses if b.get('review_count')) / len(all_businesses) * 100,
}

print(f"\n📊 Porcentaje de completitud:")
for field, percent in completeness.items():
    print(f"   {field}: {percent:.1f}%")
# Out:
# 8.2 ANÁLISIS DE CALIDAD DE DATOS
# --------------------------------------------------
# 🔍 Análisis de integridad de datos:
#    📊 Total de negocios: 200
#    ✅ Negocios con nombre: 200
#    ⭐ Negocios con calificación: 200
#    💬 Negocios con reseñas: 200
#    📍 Negocios con ubicación: 200
#    📞 Negocios con teléfono: 184
#
# 📊 Porcentaje de completitud:
#    name: 100.0%
#    rating: 100.0%
#    review_count: 100.0%

# %% [markdown]
# ## 9. Resumen Final y Preparación para Transformación

# %%
# =============================================================================
# 9.1 RESUMEN DEL PROCESO DE PAGINACIÓN
# =============================================================================
print("\n9.1 RESUMEN DEL PROCESO")
print("-" * 50)

print("🎯 Recolección de datos paginados completada exitosamente")
print(f"🏙️  Ciudad objetivo: {ciudad}")
print(f"🏢 Tipo de negocio: {params['term']}")
print(f"📊 Total de negocios obtenidos: {len(all_businesses)}")
print(f"🔢 Páginas solicitadas: {page_number - 1}")
print(f"⏱️  Tiempo total: {end_time - start_time:.2f} segundos")
print(f"📈 Eficiencia: {len(all_businesses)/(end_time - start_time):.1f} negocios/segundo")

# Calcular porcentaje del objetivo
if max_results > 0:
    porcentaje = (len(all_businesses) / max_results) * 100
    print(f"🎯 Objetivo alcanzado: {porcentaje:.1f}%")

# Guardar datos crudos para backup
try:
    timestamp = time.strftime("%Y%m%d_%H%M%S")
    filename = f"yelp_miami_restaurants_{timestamp}.json"
    
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump({'businesses': all_businesses}, f, ensure_ascii=False, indent=2)
    
    print(f"💾 Datos guardados en: {filename}")
    print(f"📦 Tamaño del archivo: {os.path.getsize(filename) / 1024:.1f} KB")
    
except Exception as e:
    print(f"⚠️ Error al guardar backup: {e}")
# Out:
# 9.1 RESUMEN DEL PROCESO
# --------------------------------------------------
# 🎯 Recolección de datos paginados completada exitosamente
# 🏙️  Ciudad objetivo: Miami
# 🏢 Tipo de negocio: restaurant
# 📊 Total de negocios obtenidos: 200
# 🔢 Páginas solicitadas: 4
# ⏱️  Tiempo total: 8.71 segundos
# 📈 Eficiencia: 23.0 negocios/segundo
# 🎯 Objetivo alcanzado: 100.0%
# 💾 Datos guardados en: yelp_miami_restaurants_20250828_124857.json
# 📦 Tamaño del archivo: 265.2 KB

# %%
# =============================================================================
# 9.2 PREPARACIÓN PARA PRÓXIMOS PASOS
# =============================================================================
print("\n9.2 PREPARACIÓN PARA TRANSFORMACIÓN")
print("-" * 50)

print("📋 Datos listos para el proceso de transformación:")
print(f"   📦 Variable: all_businesses")
print(f"   🔢 Elementos: {len(all_businesses)} negocios")
print(f"   🏢 Tipo: list of dictionaries")
print(f"   💾 Backup: {filename}")

# Crear DataFrame de muestra para preview
if all_businesses:
    df_preview = pd.DataFrame(all_businesses[:5])  # Primeros 5 para preview
    print(f"\n👀 Preview de los primeros 5 negocios:")
    print(f"   📝 Columnas disponibles: {list(df_preview.columns)}")
    print(f"   🔍 Muestra de nombres: {list(df_preview['name'].head(3))}")

print("\n" + "=" * 70)
print("✅ PAGINACIÓN COMPLETADA - LISTO PARA TRANSFORMACIÓN")
print("=" * 70)
# Out:
# 9.2 PREPARACIÓN PARA TRANSFORMACIÓN
# --------------------------------------------------
# 📋 Datos listos para el proceso de transformación:
#    📦 Variable: all_businesses
#    🔢 Elementos: 200 negocios
#    🏢 Tipo: list of dictionaries
#    💾 Backup: yelp_miami_restaurants_20250828_124857.json
#
# 👀 Preview de los primeros 5 negocios:
#    📝 Columnas disponibles: ['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'categories', 'rating', 'coordinates', 'transactions', 'location', 'phone', 'display_phone', 'distance', 'price']
#    🔍 Muestra de nombres: ['Salty Flame', "Old's Havana Cuban Bar & Cocina", 'Fratellino']
#
# ======================================================================
# ✅ PAGINACIÓN COMPLETADA - LISTO PARA TRANSFORMACIÓN
# ======================================================================

# %% [markdown]
# ### Métricas del Proceso de Paginación
#
# | Métrica | Valor |
# |---------|-------|
# | Ciudad | Miami |
# | Tipo de negocio | restaurant |
# | Resultados objetivo | 200 |
# | Resultados obtenidos | 200 |
# | Páginas solicitadas | 4 |
# | Tiempo total | 7.94 segundos |
# | Tasa de éxito | 100% |
# | Datos guardados | ✅ |
#
#
# ### Lecciones Aprendidas
#
# - La paginación es esencial para obtener datasets completos de APIs limitadas
# - Las pausas entre solicitudes previenen el rate limiting
# - La validación de datos en cada paso asegura calidad
# - Los backups automáticos protegen contra pérdida de datos

# %%
# Variables para uso en siguientes bloques
businesses_data = all_businesses
backup_filename = filename

print("🚀 Datos listos para el bloque de transformación")
# Out:
# 🚀 Datos listos para el bloque de transformación

# %%
data = response.json()

data
# Out:
# {'businesses': [{'id': '-cEQ49ZoBTUuEHjD3chNLg',
#    'alias': 'sra-martinez-coral-gables-2',
#    'name': 'Sra Martinez',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/mULs50RvocNXRF2RhyUYHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sra-martinez-coral-gables-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 66,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.7508862, 'longitude': -80.25658981687346},
#    'transactions': [],
#    'location': {'address1': '2325 Galiano St',
#     'address2': '',
#     'address3': None,
#     'city': 'Coral Gables',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2325 Galiano St', 'Coral Gables, FL 33134']},
#    'phone': '+17868605980',
#    'display_phone': '(786) 860-5980',
#    'distance': 3161.6873516776345},
#   {'id': 'l6pWbM6do9bZ5_RT5euAFQ',
#    'alias': 'boulud-sud-miami-miami-2',
#    'name': 'Boulud Sud Miami',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/6gyNUsADjASv09OIapuEqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boulud-sud-miami-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 186,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 25.7712466765723,
#     'longitude': -80.1890070619019},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '255 Biscayne Blvd Way',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33131',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['255 Biscayne Blvd Way', 'Miami, FL 33131']},
#    'phone': '+13054218800',
#    'display_phone': '(305) 421-8800',
#    'distance': 10132.234739555084},
#   {'id': '8_cuODO8G0yuzQO_fRW5kA',
#    'alias': 'toro-toro-miami-7',
#    'name': 'Toro Toro',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/cRjEON-3-t-I7isC9U2vnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toro-toro-miami-7?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1403,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.772572, 'longitude': -80.185336},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '100 Chopin Plz',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33131',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['100 Chopin Plz', 'Miami, FL 33131']},
#    'phone': '+13053724710',
#    'display_phone': '(305) 372-4710',
#    'distance': 10522.269327648733},
#   {'id': '2SJpb38UqPLwfMukVG8NKg',
#    'alias': 'the-mediterranean-kitchen-miami',
#    'name': 'The Mediterranean Kitchen',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/uuQ6iCLKtODztq54kbc1nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mediterranean-kitchen-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 8,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.796845, 'longitude': -80.276198},
#    'transactions': [],
#    'location': {'address1': '2100 NW 42nd Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33126',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2100 NW 42nd Ave', 'Miami, FL 33126']},
#    'phone': '+13058693387',
#    'display_phone': '(305) 869-3387',
#    'distance': 5041.155139614299},
#   {'id': 'G7sq7f6Zqn5QsB7ShV29AA',
#    'alias': 'brasserie-laurel-miami',
#    'name': 'Brasserie Laurel',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/UXSdKCu4I6nnFrLsiCRc6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brasserie-laurel-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 91,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.780823616241143, 'longitude': -80.1923532},
#    'transactions': [],
#    'location': {'address1': '698 NE 1st Ave',
#     'address2': 'G-170',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33132',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['698 NE 1st Ave', 'G-170', 'Miami, FL 33132']},
#    'phone': '+13053309048',
#    'display_phone': '(305) 330-9048',
#    'distance': 10080.776156591628},
#   {'id': 'LD8i6FUVc97e43GWDyVa3A',
#    'alias': 'blue-matisse-doral-2',
#    'name': 'Blue Matisse',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/_nQT-K-E8cArW8H5JwxvWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-matisse-doral-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 226,
#    'categories': [{'alias': 'newamerican', 'title': 'New American'},
#     {'alias': 'buffets', 'title': 'Buffets'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.7978477478027,
#     'longitude': -80.3358383178711},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2505 NW 87th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Doral',
#     'zip_code': '33172',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2505 NW 87th Ave', 'Doral, FL 33172']},
#    'phone': '+13054681392',
#    'display_phone': '(305) 468-1392',
#    'distance': 6930.859006096477},
#   {'id': 'kG8t6gBsarlvsxIocFUkAQ',
#    'alias': 'miranda-cuisine-and-bar-miami-springs-3',
#    'name': 'Miranda Cuisine & Bar',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/yUkfBlKT877p4ntMF3kvTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miranda-cuisine-and-bar-miami-springs-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 101,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'New American'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.80882, 'longitude': -80.2661},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4299 NW 36th St',
#     'address2': 'Fl 1',
#     'address3': 'Eb Hotel Miami',
#     'city': 'Miami Springs',
#     'zip_code': '33166',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['4299 NW 36th St',
#      'Fl 1',
#      'Eb Hotel Miami',
#      'Miami Springs, FL 33166']},
#    'phone': '+17864096490',
#    'display_phone': '(786) 409-6490',
#    'distance': 6603.133741197582},
#   {'id': 'r2R4frW2jZhEAMmlp39ZNQ',
#    'alias': 'the-wagyu-bar-miami',
#    'name': 'The Wagyu Bar',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/RawD-DZDcMd_b2iE5XsC_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wagyu-bar-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 210,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 25.750809, 'longitude': -80.231386},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2257 Coral Way',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33145',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2257 Coral Way', 'Miami, FL 33145']},
#    'phone': '+17865792498',
#    'display_phone': '(786) 579-2498',
#    'distance': 5683.468660872048},
#   {'id': 'nvwXcXSSNoV7FDWvYi_OKA',
#    'alias': 'mandolin-aegean-bistro-miami',
#    'name': 'Mandolin Aegean Bistro',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/BEDw_cqx7hcxcIOx-StEmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mandolin-aegean-bistro-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 2510,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.815960646211337,
#     'longitude': -80.19164751387174},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4312 NE 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33137',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['4312 NE 2nd Ave', 'Miami, FL 33137']},
#    'phone': '+13057499140',
#    'display_phone': '(305) 749-9140',
#    'distance': 11940.53767398886},
#   {'id': 'tW1oJJPv3kdHlw5B57Q-ZA',
#    'alias': 'el-mago-de-las-fritas-west-miami',
#    'name': 'El Mago De Las Fritas',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/nyFnW46VaXPgdUMt3dcbtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-mago-de-las-fritas-west-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 451,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 25.763315, 'longitude': -80.290834},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '5828 SW 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'West Miami',
#     'zip_code': '33144',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['5828 SW 8th St', 'West Miami, FL 33144']},
#    'phone': '+13052668486',
#    'display_phone': '(305) 266-8486',
#    'distance': 1202.0691813368524},
#   {'id': 'Tivvg8OnC753YS6n9sM2tQ',
#    'alias': 'taipa-peruvian-restaurant-coral-gables-miami-2',
#    'name': 'Taipa Peruvian Restaurant- Coral Gables',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/SHoFJ5Av-BDWJmbK-XkeLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taipa-peruvian-restaurant-coral-gables-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 49,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 25.73487689661892, 'longitude': -80.2877706},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '5751 Bird Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33155',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['5751 Bird Rd', 'Miami, FL 33155']},
#    'phone': '+13056611462',
#    'display_phone': '(305) 661-1462',
#    'distance': 1992.2339480101548},
#   {'id': 'R-nTkmkIK6Vzx-bBYzwlTQ',
#    'alias': 'sereia-coconut-grove',
#    'name': 'Sereia',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/jup42Heyk0ccWVSzU2m7Tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sereia-coconut-grove?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 25,
#    'categories': [{'alias': 'portuguese', 'title': 'Portuguese'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.725247402276544, 'longitude': -80.245059},
#    'transactions': [],
#    'location': {'address1': '3540 Main Hwy',
#     'address2': '',
#     'address3': None,
#     'city': 'Coconut Grove',
#     'zip_code': '33133',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['3540 Main Hwy', 'Coconut Grove, FL 33133']},
#    'phone': '+13059678152',
#    'display_phone': '(305) 967-8152',
#    'distance': 5287.281405235201},
#   {'id': '8cFtrhGR1jfM5dbJwPm9nw',
#    'alias': 'no-manches-que-rico-miami',
#    'name': 'No manches que rico',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/TTI6DcPlWltjxXqAeFil0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/no-manches-que-rico-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 192,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 25.76314000250607, 'longitude': -80.2963473},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '6212 SW 8th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33155',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['6212 SW 8th St', 'Miami, FL 33155']},
#    'phone': '+17862290002',
#    'display_phone': '(786) 229-0002',
#    'distance': 1417.160569403396},
#   {'id': 'DBkvlsnaPeXvynQBS1TejA',
#    'alias': 'kitchen-57-south-miami-2',
#    'name': 'Kitchen 57',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/6WspuI6b8lDI-0mHNquf1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-57-south-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 47,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.703441746848256,
#     'longitude': -80.28619494611632},
#    'transactions': [],
#    'location': {'address1': '7301 SW 57th Ct',
#     'address2': 'Ste 100',
#     'address3': '',
#     'city': 'South Miami',
#     'zip_code': '33143',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['7301 SW 57th Ct',
#      'Ste 100',
#      'South Miami, FL 33143']},
#    'phone': '+17862387179',
#    'display_phone': '(786) 238-7179',
#    'distance': 5490.681077919266},
#   {'id': '5Rq4O0gzalOQ79NenZUyqg',
#    'alias': 'tinta-y-café-miami-2',
#    'name': 'Tinta y Café',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/Vi04LaBF6_K2WUX1VmI8uA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tinta-y-caf%C3%A9-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1029,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.7592231998562,
#     'longitude': -80.2586163778576},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1315 Ponce De Leon Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1315 Ponce De Leon Blvd', 'Miami, FL 33134']},
#    'phone': '+13052850101',
#    'display_phone': '(305) 285-0101',
#    'distance': 3036.9334412947996},
#   {'id': 'H6KWK8GNk9bxUsjOOgHW1Q',
#    'alias': 'duffys-tavern-miami',
#    'name': "Duffy's Tavern",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/3wVBJ958NiGCq2FancTqVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duffys-tavern-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 252,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 25.7511641166699,
#     'longitude': -80.2875455514379},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '2108 SW 57th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33155',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2108 SW 57th Ave', 'Miami, FL 33155']},
#    'phone': '+13052646580',
#    'display_phone': '(305) 264-6580',
#    'distance': 188.90529724426034},
#   {'id': 'Z4_MkMLc_CA4kkAYOj5EzA',
#    'alias': 'pastis-miami-miami',
#    'name': 'Pastis Miami',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/fr92o1VCvYm8LL9mffJ2qQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pastis-miami-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 334,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.8011472, 'longitude': -80.2019445},
#    'transactions': [],
#    'location': {'address1': '380 NW 26th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33127',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['380 NW 26th St', 'Miami, FL 33127']},
#    'phone': '+13056863050',
#    'display_phone': '(305) 686-3050',
#    'distance': 10161.893791172422},
#   {'id': 'Gv5X1-qLTGZbwoz829-Xxg',
#    'alias': 'corona-beach-house-miami',
#    'name': 'Corona Beach House',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/G2xz0RPTLlWf3i9mq-Hx4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corona-beach-house-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 838,
#    'categories': [{'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 25.797384, 'longitude': -80.276331},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2100 NW 42nd Ave',
#     'address2': 'Terminal J gate 11',
#     'address3': 'Terminal D East, Gate D23',
#     'city': 'Miami',
#     'zip_code': '33142',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2100 NW 42nd Ave',
#      'Terminal J gate 11',
#      'Terminal D East, Gate D23',
#      'Miami, FL 33142']},
#    'phone': '+13052678510',
#    'display_phone': '(305) 267-8510',
#    'distance': 5096.319936829914},
#   {'id': 'aIQK1sw9Prr-KdUu717vRw',
#    'alias': 'dolores-but-you-can-call-me-lolita-miami',
#    'name': 'Dolores But You Can Call Me Lolita',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/90_ENPPjGAhXGMYNoZpNbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dolores-but-you-can-call-me-lolita-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1943,
#    'categories': [{'alias': 'newamerican', 'title': 'New American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 25.76427, 'longitude': -80.19354},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1000 S Miami Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33130',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1000 S Miami Ave', 'Miami, FL 33130']},
#    'phone': '+13054033103',
#    'display_phone': '(305) 403-3103',
#    'distance': 9558.898534554688},
#   {'id': 'RLgGaBUR8eT07lmrASxq-w',
#    'alias': 'recoveco-south-miami-2',
#    'name': 'Recoveco',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/sqDU7hUJJtoq_Sr1MUOa9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/recoveco-south-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 23,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tradamerican', 'title': 'American'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.702233213035516,
#     'longitude': -80.29127297508214},
#    'transactions': [],
#    'location': {'address1': '6000 SW 74th St',
#     'address2': '',
#     'address3': None,
#     'city': 'South Miami',
#     'zip_code': '33143',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['6000 SW 74th St', 'South Miami, FL 33143']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 5630.834449591328},
#   {'id': '0PGw288lzIaXPDCTNroP2w',
#    'alias': 'kuba-kitchen-miami',
#    'name': 'Kuba Kitchen',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/VOVWSgJqrFhcFbbeeDcKEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kuba-kitchen-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 73,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 25.77876, 'longitude': -80.25461},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3640 NW 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33125',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['3640 NW 7th St', 'Miami, FL 33125']},
#    'phone': '+17864097758',
#    'display_phone': '(786) 409-7758',
#    'distance': 4424.941846446275},
#   {'id': 'LvBZDGRQMbZsddjnkMIGxg',
#    'alias': 'jass-kitchen-miami',
#    'name': 'Jass Kitchen',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/nANtFHBrp7u2rz5mQ8lpLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jass-kitchen-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 207,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 25.81768, 'longitude': -80.1918},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '190 NE 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33137',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['190 NE 46th St', 'Miami, FL 33137']},
#    'phone': '+13056038748',
#    'display_phone': '(305) 603-8748',
#    'distance': 12040.7746717351},
#   {'id': 'nBIxqLEenuVRXQRTNiL3WA',
#    'alias': 'cajun-boil-miami-12',
#    'name': 'Cajun Boil',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/ulH8OdtaufQTk3fNR1S13Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cajun-boil-miami-12?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 998,
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 25.768374, 'longitude': -80.360208},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '10162 W Flagler St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33174',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['10162 W Flagler St', 'Miami, FL 33174']},
#    'phone': '+17863322641',
#    'display_phone': '(786) 332-2641',
#    'distance': 7427.33337846233},
#   {'id': 'n6xaLebNjh8sYiYh89gdEQ',
#    'alias': 'komodo-miami-miami-2',
#    'name': 'Komodo Miami',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/5r3TGA_YUAC7X48n-TUeDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/komodo-miami-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 2538,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 25.765620189138485,
#     'longitude': -80.190062945046},
#    'transactions': ['delivery'],
#    'price': '$$$$',
#    'location': {'address1': '801 Brickell Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33131',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['801 Brickell Ave', 'Miami, FL 33131']},
#    'phone': '+13055342211',
#    'display_phone': '(305) 534-2211',
#    'distance': 9919.839361683213},
#   {'id': 'xtRi4d6y-EgzgpPYFAZd1A',
#    'alias': 'alegria-by-el-rancherito-doral',
#    'name': 'Alegria By El Rancherito',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/ICudO6o_B50yfYzddfDVdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alegria-by-el-rancherito-doral?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 59,
#    'categories': [{'alias': 'colombian', 'title': 'Colombian'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.783056975940656, 'longitude': -80.3317126},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8391 NW 12th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Doral',
#     'zip_code': '33126',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['8391 NW 12th St', 'Doral, FL 33126']},
#    'phone': '+17869214691',
#    'display_phone': '(786) 921-4691',
#    'distance': 5514.478641786893},
#   {'id': '7ttBVJ-B9xQKLibnHi5_lw',
#    'alias': 'tap-42-coral-gables-coral-gables-2',
#    'name': 'Tap 42  - Coral Gables',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/PDvpjArX6jAkAfIowuK6BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tap-42-coral-gables-coral-gables-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1286,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 25.7511526879356,
#     'longitude': -80.2609388498841},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '301 Giralda Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Coral Gables',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['301 Giralda Ave', 'Coral Gables, FL 33134']},
#    'phone': '+17863911566',
#    'display_phone': '(786) 391-1566',
#    'distance': 2725.1159054417444},
#   {'id': 'p4MCaUs9QOdz2LNRG1hymA',
#    'alias': 'mother-wolf-miami',
#    'name': 'Mother Wolf',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/Hz3l9z930I9GoUnjULLkdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mother-wolf-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 74,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.81265976118508, 'longitude': -80.1910809},
#    'transactions': [],
#    'location': {'address1': '3841 NE 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33137',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['3841 NE 2nd Ave', 'Miami, FL 33137']},
#    'phone': '+13059900022',
#    'display_phone': '(305) 990-0022',
#    'distance': 11775.242175783691},
#   {'id': 'O4MKx3JGik8JgsjFinvp8w',
#    'alias': 'pizza-deli-and-company-miami',
#    'name': 'Pizza Deli & Company',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/-TYh2G_mEPIPFdcfRXhocA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-deli-and-company-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 205,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 25.75271, 'longitude': -80.28768},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1920 SW 57th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33155',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1920 SW 57th Ave', 'Miami, FL 33155']},
#    'phone': '+17867175848',
#    'display_phone': '(786) 717-5848',
#    'distance': 45.08611560885226},
#   {'id': 'wsJQm_iSAj2jLeK9jaCQdg',
#    'alias': 'hi-pot-miami-miami',
#    'name': 'Hi Pot Miami',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/oWlmUBkQ9pZ4zh91hMwgvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hi-pot-miami-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 268,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.752836, 'longitude': -80.367636},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1665 SW 107th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33165',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1665 SW 107th Ave', 'Miami, FL 33165']},
#    'phone': '+17868038618',
#    'display_phone': '(786) 803-8618',
#    'distance': 7966.784976657231},
#   {'id': 'VQhQ0LI3r9T_PHJvAeyp0Q',
#    'alias': 'blue-elephant-miami',
#    'name': 'Blue Elephant',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/ycvI62hVwYaUsXk9p8bg1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blue-elephant-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 156,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.73265, 'longitude': -80.33117},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8384 SW 40th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33155',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['8384 SW 40th St', 'Miami, FL 33155']},
#    'phone': '+17865345355',
#    'display_phone': '(786) 534-5355',
#    'distance': 4859.588626126506},
#   {'id': '3DQXvYDqwwbWDD8E98zk4A',
#    'alias': 'osaka-miami',
#    'name': 'Osaka',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/XolOQWZQyzXN3G3ZPwlPfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osaka-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 296,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.76037, 'longitude': -80.19033},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$$',
#    'location': {'address1': '1300 Brickell Bay Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33131',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1300 Brickell Bay Dr', 'Miami, FL 33131']},
#    'phone': '+17866274800',
#    'display_phone': '(786) 627-4800',
#    'distance': 9839.69882101552},
#   {'id': 'xsP-dEKEbP-l_FdVG3cspQ',
#    'alias': 'domoishi-miami',
#    'name': 'Domoishi',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/FMzdPuFFMiT5BsdD4ojrQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/domoishi-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 5,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'poke', 'title': 'Poke'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 25.770871819795737,
#     'longitude': -80.3315906971693},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '8343 W Flagler St',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33144',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['8343 W Flagler St', 'Miami, FL 33144']},
#    'phone': '+13056039631',
#    'display_phone': '(305) 603-9631',
#    'distance': 4798.022915810522},
#   {'id': 'l9cOs1k4BMGHIbKCQJQ8rg',
#    'alias': 'cotoletta-miami',
#    'name': 'Cotoletta',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/ki7gQkv-fUBE5b7suGaloA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cotoletta-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 50,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 25.727764, 'longitude': -80.245421},
#    'transactions': [],
#    'location': {'address1': '3206 Grand Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33133',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['3206 Grand Ave', 'Miami, FL 33133']},
#    'phone': '+17864097151',
#    'display_phone': '(786) 409-7151',
#    'distance': 5097.527507385271},
#   {'id': 'gosIrtHXK9sgKEyhu6j_zQ',
#    'alias': 'chimba-miami',
#    'name': 'CHIMBA',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/3KbKmlzuyyKpSxVcLQpRQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chimba-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 96,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'argentine', 'title': 'Argentine'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.8038, 'longitude': -80.19136},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2830 NE 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33137',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2830 NE 2nd Ave', 'Miami, FL 33137']},
#    'phone': '+17865585898',
#    'display_phone': '(786) 558-5898',
#    'distance': 11223.753279745702},
#   {'id': 'jTZMECkWzTarqCc_RFbCbg',
#    'alias': 'fonda-dona-leonor-coral-gables-3',
#    'name': 'Fonda Dona Leonor',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/fPwTKez4tbCHv1adnezt7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fonda-dona-leonor-coral-gables-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 3,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.74971, 'longitude': -80.2621},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '369 Miracle Mile',
#     'address2': '',
#     'address3': None,
#     'city': 'Coral Gables',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['369 Miracle Mile', 'Coral Gables, FL 33134']},
#    'phone': '+17864096960',
#    'display_phone': '(786) 409-6960',
#    'distance': 2620.420936941889},
#   {'id': 'Y6E0G3ATW4597V4jl1uxyA',
#    'alias': 'zuma-miami-2',
#    'name': 'Zuma',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/okjNWljTYzPtWA7vtDZKbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zuma-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1779,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 25.7705248376992,
#     'longitude': -80.189613327384},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '270 Biscayne Blvd Way',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33131',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['270 Biscayne Blvd Way', 'Miami, FL 33131']},
#    'phone': '+13055770277',
#    'display_phone': '(305) 577-0277',
#    'distance': 10056.771324548487},
#   {'id': 'K6zJCTpwqQ4jL5IwqJPHaw',
#    'alias': 'aromas-del-peru-west-miami-4',
#    'name': 'Aromas Del Peru',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/_7GZCQzv_nNIFrCVr-WCOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aromas-del-peru-west-miami-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 387,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 25.7639979, 'longitude': -80.2890612},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5757 SW 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'West Miami',
#     'zip_code': '33144',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['5757 SW 8th St', 'West Miami, FL 33144']},
#    'phone': '+17863470506',
#    'display_phone': '(786) 347-0506',
#    'distance': 1249.9297604463884},
#   {'id': 'owu3ufM0B_sFgh-aVsLO4g',
#    'alias': 'manta-wynwood-miami',
#    'name': 'Manta Wynwood',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/kE2LcHuOdcUde2b7FGkcXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manta-wynwood-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 291,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.80054, 'longitude': -80.19708},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '100 NW 25th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33127',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['100 NW 25th St', 'Miami, FL 33127']},
#    'phone': '+13053978275',
#    'display_phone': '(305) 397-8275',
#    'distance': 10545.138094442078},
#   {'id': '3kr1xjI-HzcIAgJVop545A',
#    'alias': 'shahs-of-kabob-coral-gables',
#    'name': 'Shahs of Kabob',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/oUw237qFBiyxDpY0TB62mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shahs-of-kabob-coral-gables?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 108,
#    'categories': [{'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'persian', 'title': 'Persian/Iranian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.74737, 'longitude': -80.25884},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2624 Ponce De Leon',
#     'address2': '',
#     'address3': None,
#     'city': 'Coral Gables',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2624 Ponce De Leon', 'Coral Gables, FL 33134']},
#    'phone': '+17865805865',
#    'display_phone': '(786) 580-5865',
#    'distance': 2990.0502644470594},
#   {'id': 'BMxexobPyjZcWHcHbTP5zA',
#    'alias': 'amsterdam-falafelshop-south-miami',
#    'name': 'Amsterdam Falafelshop',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/c2Y5oxqLlQ4wimxP6Y6nHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amsterdam-falafelshop-south-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 389,
#    'categories': [{'alias': 'falafel', 'title': 'Falafel'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.7044638, 'longitude': -80.2880526},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '5835 Sunset Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'South Miami',
#     'zip_code': '33143',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['5835 Sunset Dr', 'South Miami, FL 33143']},
#    'phone': '+17863480541',
#    'display_phone': '(786) 348-0541',
#    'distance': 5371.646391211075},
#   {'id': '0Xlb9ZjXJa1I1Yxi1QTnVA',
#    'alias': 'ashoka-indian-restaurant-miami-miami-2',
#    'name': 'Ashoka Indian Restaurant - Miami',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/pEvT_KVr1ZxEJY85ojpOeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ashoka-indian-restaurant-miami-miami-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 592,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.7732034, 'longitude': -80.3281989},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '295 NW 82nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33126',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['295 NW 82nd Ave', 'Miami, FL 33126']},
#    'phone': '+17869809626',
#    'display_phone': '(786) 980-9626',
#    'distance': 4613.704191208839},
#   {'id': 'Llejx_lL8EZtJ27_s01tkQ',
#    'alias': 'el-palacio-de-los-jugos-miami',
#    'name': 'El Palacio De Los Jugos',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/MsKYKsUSxJ197Y6obQ7_WQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-palacio-de-los-jugos-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 587,
#    'categories': [{'alias': 'markets', 'title': 'Fruits & Veggies'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 25.77104, 'longitude': -80.28858},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '5721 W Flagler St',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33144',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['5721 W Flagler St', 'Miami, FL 33144']},
#    'phone': '+17863133052',
#    'display_phone': '(786) 313-3052',
#    'distance': 2025.9347188864679},
#   {'id': 'i-fgz6ZbZ4D1uqeKa76xmw',
#    'alias': 'pho-79-miami',
#    'name': 'Pho 79',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/D34zn-uq4PG53NP5QttTgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-79-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 934,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.756192, 'longitude': -80.366591},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1415 SW 107th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33174',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1415 SW 107th Ave', 'Miami, FL 33174']},
#    'phone': '+13056037222',
#    'display_phone': '(305) 603-7222',
#    'distance': 7871.103841392393},
#   {'id': '3vR7NTYEGtKYqtwGOsuJpg',
#    'alias': 'hemingways-on-the-beach-turks-and-caicos-miami',
#    'name': 'Hemingways on the Beach Turks and Caicos',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/5u2tKvrHj_kro7RKXftNUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hemingways-on-the-beach-turks-and-caicos-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 50,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 3.3,
#    'coordinates': {'latitude': 25.7748107910156,
#     'longitude': -80.1977310180664},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Grace Bay Turks And Caicos',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['Grace Bay Turks And Caicos', 'Miami, FL']},
#    'phone': '+16499418408',
#    'display_phone': '(649) 941-8408',
#    'distance': 9373.88124735425},
#   {'id': '4YdRkZ1PB6P_FJMu73fsXQ',
#    'alias': 'casa-xabi-miami',
#    'name': 'Casa Xabi',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/uVuYzmINJl3Yr16923JBtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casa-xabi-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 73,
#    'categories': [{'alias': 'basque', 'title': 'Basque'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.727562973293985,
#     'longitude': -80.24433761779083},
#    'transactions': [],
#    'location': {'address1': '3145 Commodore Plz',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33133',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['3145 Commodore Plz', 'Miami, FL 33133']},
#    'phone': '+17866415102',
#    'display_phone': '(786) 641-5102',
#    'distance': 5203.088421007654},
#   {'id': '7zi35PQGV0jnoM7NwHWd-w',
#    'alias': 'klaw-miami-miami',
#    'name': 'Klaw Miami',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/xlCI_b-faXvzQ-XiszJ8HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/klaw-miami-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 383,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.792141525748026, 'longitude': -80.1858937},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1737 N Bayshore Dr',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33132',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['1737 N Bayshore Dr', 'Miami, FL 33132']},
#    'phone': '+13052392523',
#    'display_phone': '(305) 239-2523',
#    'distance': 11129.338842527666},
#   {'id': 'snJPBuR3TtYfapCHuZWsOQ',
#    'alias': 'manjay-miami',
#    'name': 'Manjay',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/PnErNlH_7q1kIK8Xeh3xFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/manjay-miami?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 158,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.851947, 'longitude': -80.19344},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8300 NE 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Miami',
#     'zip_code': '33138',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['8300 NE 2nd Ave', 'Miami, FL 33138']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 14537.582293044325},
#   {'id': 'rotNnhymUbXhXz-WRXlXvg',
#    'alias': 'marias-greek-restaurant-miami-3',
#    'name': "Maria's Greek Restaurant",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/HNZj6KOI370ibRVyNsQqoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marias-greek-restaurant-miami-3?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 349,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 25.7506828, 'longitude': -80.2333412},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2359 Coral Way',
#     'address2': None,
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33145',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2359 Coral Way', 'Miami, FL 33145']},
#    'phone': '+13058560938',
#    'display_phone': '(305) 856-0938',
#    'distance': 5493.4593620064925},
#   {'id': 'd4pfwfJktfuTAQM51oj_ZQ',
#    'alias': 'montys-coconut-grove-miami-5',
#    'name': "Monty's Raw Bar",
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/Ef17lmBTDDyCbMbMYNtdhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/montys-coconut-grove-miami-5?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1311,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'tikibars', 'title': 'Tiki Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.3,
#    'coordinates': {'latitude': 25.73227, 'longitude': -80.232488},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2550 S Bayshore Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Miami',
#     'zip_code': '33133',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['2550 S Bayshore Dr', 'Miami, FL 33133']},
#    'phone': '+13058563992',
#    'display_phone': '(305) 856-3992',
#    'distance': 6018.218340216072},
#   {'id': 'LnyDHTiXoPRSxk7e5qPl4w',
#    'alias': 'craft-coral-gables-coral-gables',
#    'name': 'CRAFT Coral Gables',
#    'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/g82lVF1iGYtgv1-meqNSRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/craft-coral-gables-coral-gables?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 286,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'newamerican', 'title': 'New American'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.751518923728018,
#     'longitude': -80.2574202411596},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '127 Giralda Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Coral Gables',
#     'zip_code': '33134',
#     'country': 'US',
#     'state': 'FL',
#     'display_address': ['127 Giralda Ave', 'Coral Gables, FL 33134']},
#    'phone': '+17867726932',
#    'display_phone': '(786) 772-6932',
#    'distance': 3074.6633961134767}],
#  'total': 5700,
#  'region': {'center': {'longitude': -80.2880859375,
#    'latitude': 25.752753731496888}}}

# %%
# =============================================================================
# BLOQUE 3: EXTRACCIÓN Y TRANSFORMACIÓN DE DATOS YELP
# =============================================================================
print("=" * 70)
print("BLOQUE 3: EXTRACCIÓN Y TRANSFORMACIÓN DE DATOS YELP")
print("=" * 70)
# Out:
# ======================================================================
# BLOQUE 3: EXTRACCIÓN Y TRANSFORMACIÓN DE DATOS YELP
# ======================================================================

# %% [markdown]
# ## 10. Extracción y Procesamiento de Datos de la API
#
# ### 🎯 Objetivo:
# Transformar los datos JSON brutos de la API Yelp en un DataFrame estructurado y limpio, listo para análisis y integración con los datos de clientes.

# %%
# =============================================================================
# 10.1 VERIFICACIÓN DE DATOS OBTENIDOS
# =============================================================================
print("\n10.1 VERIFICACIÓN DE DATOS OBTENIDOS")
print("-" * 50)

print(f"📊 Total de negocios obtenidos: {len(all_businesses)}")

if len(all_businesses) > 0:
    print("✅ Datos obtenidos exitosamente de la API de Yelp")
    data = {'businesses': all_businesses}  # Crear estructura compatible
else:
    print("❌ No se obtuvieron datos de la API")
    exit()

# Verificar estructura del primer negocio
if data['businesses']:
    primer_negocio = data['businesses'][0]
    print(f"👀 Primer negocio: {primer_negocio.get('name', 'N/A')}")
    print(f"🏷️  Tipo de datos: {type(primer_negocio)}")
# Out:
# 10.1 VERIFICACIÓN DE DATOS OBTENIDOS
# --------------------------------------------------
# 📊 Total de negocios obtenidos: 200
# ✅ Datos obtenidos exitosamente de la API de Yelp
# 👀 Primer negocio: Salty Flame
# 🏷️  Tipo de datos: <class 'dict'>

# %%
# =============================================================================
# 10.2 ANÁLISIS DE ESTRUCTURA DE DATOS
# =============================================================================
print("\n10.2 ANÁLISIS DE ESTRUCTURA DE DATOS")
print("-" * 50)

if data['businesses']:
    primer_negocio = data['businesses'][0]
    print("🔑 Claves principales del primer negocio:")
    for i, key in enumerate(list(primer_negocio.keys())[:10], 1):  # Mostrar primeras 10 claves
        print(f"   {i}. {key}")
    
    print(f"\n📋 Total de claves: {len(primer_negocio.keys())}")
    
    # Mostrar ejemplo de datos anidados
    print("\n🏢 Ejemplo de datos de ubicación:")
    if 'location' in primer_negocio:
        for key, value in list(primer_negocio['location'].items())[:3]:
            print(f"   📍 {key}: {value}")
    
    print("\n⭐ Ejemplo de datos de categorías:")
    if 'categories' in primer_negocio:
        for i, cat in enumerate(primer_negocio['categories'][:3], 1):
            print(f"   🏷️  {i}. {cat.get('title', 'N/A')}")
# Out:
# 10.2 ANÁLISIS DE ESTRUCTURA DE DATOS
# --------------------------------------------------
# 🔑 Claves principales del primer negocio:
#    1. id
#    2. alias
#    3. name
#    4. image_url
#    5. is_closed
#    6. url
#    7. review_count
#    8. categories
#    9. rating
#    10. coordinates
#
# 📋 Total de claves: 15
#
# 🏢 Ejemplo de datos de ubicación:
#    📍 address1: 1414 Brickell Ave
#    📍 address2: None
#    📍 address3:
#
# ⭐ Ejemplo de datos de categorías:
#    🏷️  1. Asian Fusion
#    🏷️  2. Steakhouses
#    🏷️  3. Cocktail Bars

# %% [markdown]
# ## 11. Función de Extracción de Datos Relevantes

# %%
# =============================================================================
# 11.1 FUNCIÓN DE EXTRACCIÓN DE DATOS
# =============================================================================
print("\n11.1 FUNCIÓN DE EXTRACCIÓN DE DATOS")
print("-" * 50)

def extraer_datos_negocios(data_json):
    """
    Extrae y transforma datos relevantes de la respuesta JSON de Yelp
    en un formato estructurado para análisis.
    
    Parameters:
    data_json (dict): Datos JSON de la API Yelp
    
    Returns:
    list: Lista de diccionarios con datos estructurados
    """
    negocios = []
    
    for business in data_json.get('businesses', []):
        # Obtener datos anidados de manera segura
        coordinates = business.get('coordinates', {})
        location = business.get('location', {})
        categories = business.get('categories', [])
        
        # Extraer información relevante
        negocio_info = {
            # Identificadores únicos
            'id_yelp': business.get('id'),
            'alias': business.get('alias'),
            
            # Información básica
            'nombre': business.get('name'),
            'calificacion': business.get('rating'),
            'numero_resenas': business.get('review_count'),
            'precio_nivel': business.get('price', 'No especificado'),
            'esta_cerrado': business.get('is_closed', False),
            
            # Categorías y tipo de negocio
            'categorias': ', '.join([cat['title'] for cat in categories]),
            'categorias_lista': [cat['title'] for cat in categories],
            
            # Ubicación y coordenadas
            'direccion_completa': ', '.join(location.get('display_address', [])),
            'direccion_calle': location.get('address1'),
            'ciudad': location.get('city'),
            'estado': location.get('state'),
            'codigo_postal': location.get('zip_code'),
            'pais': location.get('country'),
            'latitud': coordinates.get('latitude'),
            'longitud': coordinates.get('longitud'),
            
            # Contacto e información adicional
            'telefono': business.get('phone', 'No disponible'),
            'url_yelp': business.get('url'),
            'url_imagen': business.get('image_url'),
            
            # Métricas de desempeño
            'distancia_metros': business.get('distance'),  # En metros
            'transacciones': ', '.join(business.get('transactions', [])),
            
            # Información de horarios (si está disponible)
            'horarios_disponibles': 'hours' in business
        }
        negocios.append(negocio_info)
    
    return negocios

print("✅ Función de extracción definida correctamente")
print("📋 Campos a extraer: 25 campos relevantes")
# Out:
# 11.1 FUNCIÓN DE EXTRACCIÓN DE DATOS
# --------------------------------------------------
# ✅ Función de extracción definida correctamente
# 📋 Campos a extraer: 25 campos relevantes

# %%
# =============================================================================
# 11.2 EJECUCIÓN DE LA EXTRACCIÓN
# =============================================================================
print("\n11.2 EJECUCIÓN DE LA EXTRACCIÓN")
print("-" * 50)

print("⏳ Extrayendo datos de negocios...")
start_time = time.time()

negocios_yelp = extraer_datos_negocios(data)
end_time = time.time()

print(f"✅ Datos extraídos de {len(negocios_yelp)} negocios")
print(f"⏱️  Tiempo de extracción: {end_time - start_time:.2f} segundos")
print(f"📊 Tasa: {len(negocios_yelp)/(end_time - start_time):.1f} negocios/segundo")

# Mostrar ejemplo del primer negocio extraído
if negocios_yelp:
    print("\n👀 Ejemplo de datos extraídos (primer negocio):")
    primer_extraido = negocios_yelp[0]
    for key, value in list(primer_extraido.items())[:5]:  # Primeros 5 campos
        print(f"   {key}: {value}")
# Out:
# 11.2 EJECUCIÓN DE LA EXTRACCIÓN
# --------------------------------------------------
# ⏳ Extrayendo datos de negocios...
# ✅ Datos extraídos de 200 negocios
# ⏱️  Tiempo de extracción: 0.00 segundos
# 📊 Tasa: 72328.1 negocios/segundo
#
# 👀 Ejemplo de datos extraídos (primer negocio):
#    id_yelp: K3ukx2e11xTRtYBU01dmrA
#    alias: salty-flame-miami
#    nombre: Salty Flame
#    calificacion: 4.4
#    numero_resenas: 194

# %% [markdown]
# ## 12. Creación y Limpieza del DataFrame

# %%
# =============================================================================
# 12.1 CREACIÓN DEL DATAFRAME
# =============================================================================
print("\n12.1 CREACIÓN DEL DATAFRAME")
print("-" * 50)

print("🏗️ Creando DataFrame a partir de datos extraídos...")
df_yelp = pd.DataFrame(negocios_yelp)

print(f"✅ DataFrame creado exitosamente")
print(f"📐 Dimensiones: {df_yelp.shape[0]} filas × {df_yelp.shape[1]} columnas")
print(f"📊 Columnas: {list(df_yelp.columns)}")
print(f"💾 Memoria inicial: {df_yelp.memory_usage(deep=True).sum() / 1024:.2f} KB")

# Optimizar tipos de datos
print("\n🔄 Optimizando tipos de datos...")
optimizaciones = {
    'calificacion': 'float32',
    'numero_resenas': 'int32',
    'latitud': 'float32',
    'longitud': 'float32',
    'distancia_metros': 'float32',
    'esta_cerrado': 'bool'
}

for col, dtype in optimizaciones.items():
    if col in df_yelp.columns:
        df_yelp[col] = df_yelp[col].astype(dtype)
        print(f"   ✅ {col} → {dtype}")

print(f"💾 Memoria después de optimización: {df_yelp.memory_usage(deep=True).sum() / 1024:.2f} KB")
# Out:
# 12.1 CREACIÓN DEL DATAFRAME
# --------------------------------------------------
# 🏗️ Creando DataFrame a partir de datos extraídos...
# ✅ DataFrame creado exitosamente
# 📐 Dimensiones: 200 filas × 23 columnas
# 📊 Columnas: ['id_yelp', 'alias', 'nombre', 'calificacion', 'numero_resenas', 'precio_nivel', 'esta_cerrado', 'categorias', 'categorias_lista', 'direccion_completa', 'direccion_calle', 'ciudad', 'estado', 'codigo_postal', 'pais', 'latitud', 'longitud', 'telefono', 'url_yelp', 'url_imagen', 'distancia_metros', 'transacciones', 'horarios_disponibles']
# 💾 Memoria inicial: 258.12 KB
#
# 🔄 Optimizando tipos de datos...
#    ✅ calificacion → float32
#    ✅ numero_resenas → int32
#    ✅ latitud → float32
#    ✅ longitud → float32
#    ✅ distancia_metros → float32
#    ✅ esta_cerrado → bool
# 💾 Memoria después de optimización: 251.09 KB

# %%
# =============================================================================
# 12.2 ANÁLISIS DE VALORES NULOS
# =============================================================================
print("\n12.2 ANÁLISIS DE VALORES NULOS")
print("-" * 50)

# Crear resumen detallado de valores nulos
null_summary = pd.DataFrame({
    'Valores_Nulos': df_yelp.isnull().sum(),
    'Porcentaje_Nulos': (df_yelp.isnull().sum() / len(df_yelp)) * 100,
    'Tipo_Dato': df_yelp.dtypes
}).sort_values('Porcentaje_Nulos', ascending=False)

print("📋 Resumen de valores nulos por columna:")
print(null_summary[null_summary['Valores_Nulos'] > 0])
# Out:
# 12.2 ANÁLISIS DE VALORES NULOS
# --------------------------------------------------
# 📋 Resumen de valores nulos por columna:
#           Valores_Nulos  Porcentaje_Nulos Tipo_Dato
# longitud            200             100.0   float32

# %% [markdown]
# ## 13. Estrategias de Limpieza de Datos

# %%
# =============================================================================
# 13.1 ESTRATEGIA DE LIMPIEZA DE DATOS
# =============================================================================
print("\n13.1 ESTRATEGIA DE LIMPIEZA DE DATOS")
print("-" * 50)

# Crear copia para limpieza
df_yelp_clean = df_yelp.copy()
print("✅ Copia del DataFrame creada para limpieza")
print("\n🛠️ Aplicando estrategias de limpieza...")

# Definir estrategias por tipo de columna
estrategias_limpieza = {
    'numeric': ['calificacion', 'numero_resenas', 'latitud', 'longitud', 'distancia_metros'],
    'categorical': ['precio_nivel', 'ciudad', 'estado', 'codigo_postal', 'pais'],
    'text': ['direccion_completa', 'direccion_calle', 'categorias', 'telefono'],
    'url': ['url_yelp', 'url_imagen'],
    'boolean': ['esta_cerrado', 'horarios_disponibles']
}

print("📋 Estrategias aplicadas:")

# a. Columnas numéricas: imputar con mediana (con validación)
for col in estrategias_limpieza['numeric']:
    if col in df_yelp_clean.columns and df_yelp_clean[col].isnull().any():
        nulos_antes = df_yelp_clean[col].isnull().sum()
        
        # Verificar si hay valores válidos para calcular la mediana
        valores_validos = df_yelp_clean[col].dropna()
        
        if len(valores_validos) > 0:
            mediana = valores_validos.median()
            df_yelp_clean[col] = df_yelp_clean[col].fillna(mediana)
            print(f"   🔢 {col}: {nulos_antes} nulos → mediana ({mediana:.2f})")
        else:
            # Si todos los valores son nulos, llenar con 0 o un valor por defecto
            valor_defecto = 0 if col in ['latitud', 'longitud'] else df_yelp_clean[col].dtype.type(0)
            df_yelp_clean[col] = df_yelp_clean[col].fillna(valor_defecto)
            print(f"   ⚠️  {col}: {nulos_antes} nulos → valor por defecto ({valor_defecto}) - TODOS eran nulos")

# b. Columnas categóricas
for col in estrategias_limpieza['categorical']:
    if col in df_yelp_clean.columns and df_yelp_clean[col].isnull().any():
        nulos_antes = df_yelp_clean[col].isnull().sum()
        
        if col == 'precio_nivel':
            df_yelp_clean[col] = df_yelp_clean[col].fillna('No especificado')
            print(f"   💰 {col}: {nulos_antes} nulos → 'No especificado'")
        else:
            moda_values = df_yelp_clean[col].mode()
            if not moda_values.empty:
                moda = moda_values[0]
            else:
                moda = 'Desconocido'
            df_yelp_clean[col] = df_yelp_clean[col].fillna(moda)
            print(f"   🏷️  {col}: {nulos_antes} nulos → moda ('{moda}')")

# c. Columnas de texto: pd.NA para missing values explícitos
for col in estrategias_limpieza['text']:
    if col in df_yelp_clean.columns and df_yelp_clean[col].isnull().any():
        nulos_antes = df_yelp_clean[col].isnull().sum()
        df_yelp_clean[col] = df_yelp_clean[col].fillna(pd.NA)
        print(f"   📝 {col}: {nulos_antes} nulos → pd.NA")

# d. Columnas booleanas: False por defecto
for col in estrategias_limpieza['boolean']:
    if col in df_yelp_clean.columns and df_yelp_clean[col].isnull().any():
        nulos_antes = df_yelp_clean[col].isnull().sum()
        df_yelp_clean[col] = df_yelp_clean[col].fillna(False)
        print(f"   ✅ {col}: {nulos_antes} nulos → False")

print("\n🔍 Verificación post-limpieza:")
print("Valores nulos restantes por columna:")
nulos_restantes = df_yelp_clean.isnull().sum()
for col, nulos in nulos_restantes[nulos_restantes > 0].items():
    print(f"   ❌ {col}: {nulos} nulos restantes")

if nulos_restantes.sum() == 0:
    print("   ✅ ¡No hay valores nulos restantes!")
# Out:
# 13.1 ESTRATEGIA DE LIMPIEZA DE DATOS
# --------------------------------------------------
# ✅ Copia del DataFrame creada para limpieza
#
# 🛠️ Aplicando estrategias de limpieza...
# 📋 Estrategias aplicadas:
#    ⚠️  longitud: 200 nulos → valor por defecto (0) - TODOS eran nulos
#
# 🔍 Verificación post-limpieza:
# Valores nulos restantes por columna:
#    ✅ ¡No hay valores nulos restantes!

# %%
# =============================================================================
# 13.2 VERIFICACIÓN POST-LIMPIEZA
# =============================================================================
print("\n13.2 VERIFICACIÓN POST-LIMPIEZA")
print("-" * 50)

# Verificación completa
nulos_finales = df_yelp_clean.isnull().sum().sum()
print(f"🔍 Valores nulos totales después de limpieza: {nulos_finales}")

if nulos_finales == 0:
    print("✅ Todos los valores nulos han sido tratados adecuadamente")
else:
    nulos_restantes = df_yelp_clean.isnull().sum()[df_yelp_clean.isnull().sum() > 0]
    print("⚠️ Valores nulos restantes:")
    for col, count in nulos_restantes.items():
        print(f"   {col}: {count} nulos")

print(f"\n💾 Memoria final: {df_yelp_clean.memory_usage(deep=True).sum() / 1024:.2f} KB")
print(f"📊 Reducción de memoria: {(df_yelp.memory_usage(deep=True).sum() - df_yelp_clean.memory_usage(deep=True).sum()) / 1024:.2f} KB")
# Out:
# 13.2 VERIFICACIÓN POST-LIMPIEZA
# --------------------------------------------------
# 🔍 Valores nulos totales después de limpieza: 0
# ✅ Todos los valores nulos han sido tratados adecuadamente
#
# 💾 Memoria final: 251.09 KB
# 📊 Reducción de memoria: 0.00 KB

# %% [markdown]
# ## 14. Análisis Exploratorio Inicial

# %%
# =============================================================================
# 14.1 ANÁLISIS EXPLORATORIO INICIAL
# =============================================================================
print("\n14.1 ANÁLISIS EXPLORATORIO INICIAL")
print("-" * 50)

print("📊 Resumen del dataset limpio:")
print(df_yelp_clean.info())

print("\n📈 Estadísticas descriptivas - Métricas numéricas:")
numeric_stats = df_yelp_clean[['calificacion', 'numero_resenas', 'distancia_metros']].describe()
print(numeric_stats)

print("\n⭐ Distribución de calificaciones:")
calificacion_dist = df_yelp_clean['calificacion'].value_counts().sort_index()
for rating, count in calificacion_dist.items():
    print(f"   {rating}⭐: {count} negocios ({count/len(df_yelp_clean)*100:.1f}%)")

print("\n💰 Distribución de niveles de precio:")
precio_dist = df_yelp_clean['precio_nivel'].value_counts()
for precio, count in precio_dist.items():
    print(f"   {precio}: {count} negocios ({count/len(df_yelp_clean)*100:.1f}%)")

# Análisis de categorías
print("\n🏷️  Top 10 categorías más comunes:")
from collections import Counter

todas_categorias = []
for categorias in df_yelp_clean['categorias']:
    if pd.notna(categorias) and categorias != '':
        todas_categorias.extend([cat.strip() for cat in str(categorias).split(',')])

categorias_count = Counter(todas_categorias)
for categoria, count in categorias_count.most_common(10):
    porcentaje = (count / len(df_yelp_clean)) * 100
    print(f"   {categoria}: {count} ({porcentaje:.1f}%)")
# Out:
# 14.1 ANÁLISIS EXPLORATORIO INICIAL
# --------------------------------------------------
# 📊 Resumen del dataset limpio:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_yelp               200 non-null    object
#  1   alias                 200 non-null    object
#  2   nombre                200 non-null    object
#  3   calificacion          200 non-null    float32
#  4   numero_resenas        200 non-null    int32
#  5   precio_nivel          200 non-null    object
#  6   esta_cerrado          200 non-null    bool
#  7   categorias            200 non-null    object
#  8   categorias_lista      200 non-null    object
#  9   direccion_completa    200 non-null    object
#  10  direccion_calle       200 non-null    object
#  11  ciudad                200 non-null    object
#  12  estado                200 non-null    object
#  13  codigo_postal         200 non-null    object
#  14  pais                  200 non-null    object
#  15  latitud               200 non-null    float32
#  16  longitud              200 non-null    float32
#  17  telefono              200 non-null    object
#  18  url_yelp              200 non-null    object
#  19  url_imagen            200 non-null    object
#  20  distancia_metros      200 non-null    float32
#  21  transacciones         200 non-null    object
#  22  horarios_disponibles  200 non-null    bool
# dtypes: bool(2), float32(4), int32(1), object(16)
# memory usage: 29.4+ KB
# None
#
# 📈 Estadísticas descriptivas - Métricas numéricas:
#        calificacion  numero_resenas  distancia_metros
# count    200.000000      200.000000        200.000000
# mean       4.342500      535.130000       5853.708984
# std        0.328456      838.874313       3188.751953
# min        2.700000        1.000000         45.086117
# 25%        4.175000       87.500000       3093.406189
# 50%        4.400000      246.500000       5287.870117
# 75%        4.500000      657.000000       8309.098999
# max        5.000000     6887.000000      14537.582031
#
# ⭐ Distribución de calificaciones:
#    2.700000047683716⭐: 1 negocios (0.5%)
#    3.299999952316284⭐: 2 negocios (1.0%)
#    3.5999999046325684⭐: 4 negocios (2.0%)
#    3.700000047683716⭐: 1 negocios (0.5%)
#    3.799999952316284⭐: 3 negocios (1.5%)
#    3.9000000953674316⭐: 8 negocios (4.0%)
#    4.0⭐: 13 negocios (6.5%)
#    4.099999904632568⭐: 18 negocios (9.0%)
#    4.199999809265137⭐: 15 negocios (7.5%)
#    4.300000190734863⭐: 25 negocios (12.5%)
#    4.400000095367432⭐: 33 negocios (16.5%)
#    4.5⭐: 31 negocios (15.5%)
#    4.599999904632568⭐: 17 negocios (8.5%)
#    4.699999809265137⭐: 14 negocios (7.0%)
#    4.800000190734863⭐: 7 negocios (3.5%)
#    4.900000095367432⭐: 1 negocios (0.5%)
#    5.0⭐: 7 negocios (3.5%)
#
# 💰 Distribución de niveles de precio:
#    $$: 99 negocios (49.5%)
#    No especificado: 60 negocios (30.0%)
#    $$$: 21 negocios (10.5%)
#    $: 13 negocios (6.5%)
#    $$$$: 7 negocios (3.5%)
#
# 🏷️  Top 10 categorías más comunes:
#    Seafood: 24 (12.0%)
#    Cocktail Bars: 20 (10.0%)
#    Mediterranean: 18 (9.0%)
#    New American: 18 (9.0%)
#    Breakfast & Brunch: 17 (8.5%)
#    Steakhouses: 16 (8.0%)
#    Cuban: 16 (8.0%)
#    Italian: 16 (8.0%)
#    Latin American: 15 (7.5%)
#    Desserts: 14 (7.0%)

# %%
# =============================================================================
# 14.2 GUARDADO DE DATOS PROCESADOS
# =============================================================================
print("\n14.2 GUARDADO DE DATOS PROCESADOS")
print("-" * 50)

# Guardar datasets para uso futuro
timestamp = time.strftime("%Y%m%d_%H%M%S")
archivo_original = f"yelp_miami_original_{timestamp}.csv"
archivo_limpio = f"yelp_miami_limpio_{timestamp}.csv"

df_yelp.to_csv(archivo_original, index=False, encoding='utf-8')
df_yelp_clean.to_csv(archivo_limpio, index=False, encoding='utf-8')

print(f"✅ Datos originales guardados: {archivo_original}")
print(f"✅ Datos limpios guardados: {archivo_limpio}")
print(f"📦 Tamaño original: {os.path.getsize(archivo_original) / 1024:.1f} KB")
print(f"📦 Tamaño limpio: {os.path.getsize(archivo_limpio) / 1024:.1f} KB")

print("\n" + "=" * 70)
print("✅ EXTRACCIÓN Y TRANSFORMACIÓN COMPLETADA")
print("=" * 70)
# Out:
# 14.2 GUARDADO DE DATOS PROCESADOS
# --------------------------------------------------
# ✅ Datos originales guardados: yelp_miami_original_20250828_124858.csv
# ✅ Datos limpios guardados: yelp_miami_limpio_20250828_124858.csv
# 📦 Tamaño original: 102.7 KB
# 📦 Tamaño limpio: 103.3 KB
#
# ======================================================================
# ✅ EXTRACCIÓN Y TRANSFORMACIÓN COMPLETADA
# ======================================================================

# %%
# Variables para uso en siguientes bloques
yelp_data_clean = df_yelp_clean
yelp_data_raw = df_yelp

print("🚀 Datos listos para análisis e integración")
# Out:
# 🚀 Datos listos para análisis e integración

# %% [markdown]
# Visualizacion del Dataset:

# %%
data.keys()
data['businesses']
df_yelp = pd.json_normalize(data['businesses'])
df_yelp
# Out:
#                          id                                   alias  \
# 0    K3ukx2e11xTRtYBU01dmrA                       salty-flame-miami
# 1    UXHxLN3DcDGI57uDIfCuJA  olds-havana-cuban-bar-and-cocina-miami
# 2    oxtMfBGmVNE18pFVuw7lFg               fratellino-coral-gables-2
# 3    ix8ifP1jQM9ektdVAs19sQ                 crazy-about-you-miami-3
# 4    WqIBKxRUPXH3NqTViAHLxQ       bayshore-club-bar-and-grill-miami
# ..                      ...                                     ...
# 195  7zi35PQGV0jnoM7NwHWd-w                        klaw-miami-miami
# 196  snJPBuR3TtYfapCHuZWsOQ                            manjay-miami
# 197  rotNnhymUbXhXz-WRXlXvg         marias-greek-restaurant-miami-3
# 198  d4pfwfJktfuTAQM51oj_ZQ            montys-coconut-grove-miami-5
# 199  LnyDHTiXoPRSxk7e5qPl4w         craft-coral-gables-coral-gables
#
#                                 name  \
# 0                        Salty Flame
# 1    Old's Havana Cuban Bar & Cocina
# 2                         Fratellino
# 3                    Crazy About You
# 4          Bayshore Club Bar & Grill
# ..                               ...
# 195                       Klaw Miami
# 196                           Manjay
# 197         Maria's Greek Restaurant
# 198                  Monty's Raw Bar
# 199               CRAFT Coral Gables
#
#                                              image_url  is_closed  \
# 0    https://s3-media0.fl.yelpcdn.com/bphoto/_6wShT...      False
# 1    https://s3-media0.fl.yelpcdn.com/bphoto/OyMD-x...      False
# 2    https://s3-media0.fl.yelpcdn.com/bphoto/OPS9ib...      False
# 3    https://s3-media0.fl.yelpcdn.com/bphoto/vvQBoP...      False
# 4    https://s3-media0.fl.yelpcdn.com/bphoto/B7tTbJ...      False
# ..                                                 ...        ...
# 195  https://s3-media0.fl.yelpcdn.com/bphoto/xlCI_b...      False
# 196  https://s3-media0.fl.yelpcdn.com/bphoto/PnErNl...      False
# 197  https://s3-media0.fl.yelpcdn.com/bphoto/HNZj6K...      False
# 198  https://s3-media0.fl.yelpcdn.com/bphoto/Ef17lm...      False
# 199  https://s3-media0.fl.yelpcdn.com/bphoto/g82lVF...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/salty-flame-miami?adj...           194
# 1    https://www.yelp.com/biz/olds-havana-cuban-bar...          2997
# 2    https://www.yelp.com/biz/fratellino-coral-gabl...          1813
# 3    https://www.yelp.com/biz/crazy-about-you-miami...          2787
# 4    https://www.yelp.com/biz/bayshore-club-bar-and...           947
# ..                                                 ...           ...
# 195  https://www.yelp.com/biz/klaw-miami-miami?adju...           383
# 196  https://www.yelp.com/biz/manjay-miami?adjust_c...           158
# 197  https://www.yelp.com/biz/marias-greek-restaura...           349
# 198  https://www.yelp.com/biz/montys-coconut-grove-...          1311
# 199  https://www.yelp.com/biz/craft-coral-gables-co...           286
#
#                                             categories  rating  \
# 0    [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.4
# 1    [{'alias': 'cuban', 'title': 'Cuban'}, {'alias...     4.4
# 2           [{'alias': 'italian', 'title': 'Italian'}]     4.8
# 3    [{'alias': 'mediterranean', 'title': 'Mediterr...     4.2
# 4    [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.3
# ..                                                 ...     ...
# 195  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.4
# 196     [{'alias': 'caribbean', 'title': 'Caribbean'}]     4.3
# 197  [{'alias': 'greek', 'title': 'Greek'}, {'alias...     4.1
# 198  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.3
# 199  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.4
#
#                                    transactions  ... coordinates.longitude  \
# 0                            [pickup, delivery]  ...            -80.192670
# 1              [restaurant_reservation, pickup]  ...            -80.219238
# 2    [restaurant_reservation, pickup, delivery]  ...            -80.260110
# 3            [restaurant_reservation, delivery]  ...            -80.188986
# 4                                            []  ...            -80.234162
# ..                                          ...  ...                   ...
# 195                                          []  ...            -80.185894
# 196                          [delivery, pickup]  ...            -80.193440
# 197                          [delivery, pickup]  ...            -80.233341
# 198                          [delivery, pickup]  ...            -80.232488
# 199                          [delivery, pickup]  ...            -80.257420
#
#         location.address1  location.address2  location.address3  \
# 0       1414 Brickell Ave               None
# 1          1442 SW 8th St                                  None
# 2        264 Miracle Mile
# 3    1155 Brickell Bay Dr            Ste 101
# 4    3391 Pan American Dr               None               None
# ..                    ...                ...                ...
# 195    1737 N Bayshore Dr               None
# 196       8300 NE 2nd Ave                                  None
# 197        2359 Coral Way               None
# 198    2550 S Bayshore Dr
# 199       127 Giralda Ave                                  None
#
#      location.city location.zip_code location.country location.state  \
# 0            Miami             33131               US             FL
# 1            Miami             33135               US             FL
# 2     Coral Gables             33134               US             FL
# 3            Miami             33131               US             FL
# 4            Miami             33133               US             FL
# ..             ...               ...              ...            ...
# 195          Miami             33132               US             FL
# 196          Miami             33138               US             FL
# 197          Miami             33145               US             FL
# 198          Miami             33133               US             FL
# 199   Coral Gables             33134               US             FL
#
#                              location.display_address price
# 0                [1414 Brickell Ave, Miami, FL 33131]   NaN
# 1                   [1442 SW 8th St, Miami, FL 33135]    $$
# 2          [264 Miracle Mile, Coral Gables, FL 33134]   $$$
# 3    [1155 Brickell Bay Dr, Ste 101, Miami, FL 33131]    $$
# 4             [3391 Pan American Dr, Miami, FL 33133]   $$$
# ..                                                ...   ...
# 195             [1737 N Bayshore Dr, Miami, FL 33132]  $$$$
# 196                [8300 NE 2nd Ave, Miami, FL 33138]    $$
# 197                 [2359 Coral Way, Miami, FL 33145]    $$
# 198             [2550 S Bayshore Dr, Miami, FL 33133]    $$
# 199         [127 Giralda Ave, Coral Gables, FL 33134]    $$
#
# [200 rows x 24 columns]

# %%
# GUARDAR DATOS YELP PARA EL AVANCE 3
df_yelp_clean.to_csv('yelp_miami_limpio.csv', index=False)
print("✅ Datos Yelp de Miami guardados para Avance #3")
# Out:
# ✅ Datos Yelp de Miami guardados para Avance #3
